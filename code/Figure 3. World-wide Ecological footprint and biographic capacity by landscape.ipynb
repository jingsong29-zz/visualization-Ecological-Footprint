# %%
#Figure 1
#https://plot.ly/python/filled-area-animation/

# %%
import plotly
plotly.__version__
# Out:
# '2.5.1'

# %%
import os
import pandas as pd

# %%
import plotly.plotly as py
from plotly.grid_objs import Grid, Column
from plotly.tools import FigureFactory as FF 
import plotly.graph_objs as go
import time
from datetime import datetime
import numpy as np
import pandas as pd

# %%
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
plotly.tools.set_credentials_file(username='fliu23', api_key='UX4p9CdJUmj67JmpsEuL')

# %%
#location of footprint data
path='../data/footprint/country_trends'

# %%
num_earth = pd.read_csv(os.path.join(path, "world/Ecological Footprint (Number of Earths).csv"))

# %%
ef_gha = pd.read_csv(os.path.join(path, "world/Ecological Footprint vs Biocapacity (gha).csv"))

# %%
ef_person = pd.read_csv(os.path.join(path, "world/Ecological Footprint vs Biocapacity (gha per person).csv"))
ef_person.head(2)
# Out:
#   Country Name Short Name  year        Record  Built-up Land    Carbon  \
# 0        World    º World  1961  EFConsPerCap       0.026267  1.005262
# 1        World    º World  1961  BiocapPerCap       0.026267  0.000000
#
#    Cropland  Fishing Grounds  Forest Products  Grazing Land     Total  \
# 0  0.464565         0.095635         0.430615      0.265488  2.287829
# 1  0.464565         0.366753         1.787426      0.480558  3.125569
#
#   Data Quality Score isoa2
# 0                 3A  null
# 1                 3A  null

# %%
#ef_person_EF=ef_person.loc[ef_person['Record']=='EFConsPerCap', 'Total'].tolist()

# %% [markdown]
# ### EF and BC per capita

# %%
ef_person_EF=ef_person.loc[ef_person['Record']=='EFConsPerCap'].reset_index()
ef_person_BC=ef_person.loc[ef_person['Record']=='BiocapPerCap'].reset_index()

# %%
source_list = ef_person_EF.columns.tolist()[5:11]
source_list
# Out:
# ['Built-up Land',
#  'Carbon',
#  'Cropland',
#  'Fishing Grounds',
#  'Forest Products',
#  'Grazing Land']

# %%
data=[]
#Aggregate Incident number by year
#new_total = crime_data.groupby('year')['IncidntNum'].sum().reset_index().rename(columns={'IncidntNum':'yeartotal'}) 
#Aggregate incident number by category by year and calculate proportion of each category per year.


for source in source_list:
    #new_df = crime_data.loc[crime_data['Category']==crime, ].groupby('year')['IncidntNum'].sum().reset_index()
    #new = new_df.merge(new_total, how = 'left', on ='year')
    #new['pert'] = new['IncidntNum']/new['yeartotal']*100
    
    trace =go.Bar(
                x=ef_person_EF['year'],
                y=ef_person_EF[source],
                name=source
        )
    data.append(trace)
    
layout = go.Layout(title = 'Figure 1.1 World Ecological Footprint per capita by source',
              xaxis = dict(title = 'Year', autotick=False),
              yaxis = dict(title = 'Ecological Footprint per capita'),
              barmode='stack',
              showlegend=True)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar-stacked')
# Out:
# <div id="4b1f3c88-b83e-41cc-949d-aa569f1e2915" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4b1f3c88-b83e-41cc-949d-aa569f1e2915", [{"y": [0.026267061753895, 0.027278565418383, 0.0274128251534238, 0.0281849376776406, 0.0285430405600116, 0.0303551263842964, 0.0311041599352478, 0.0316903676244591, 0.0320560276970156, 0.0329988627664111, 0.0346076561485223, 0.0337565142559032, 0.0355946788919016, 0.0346187728935319, 0.0350992216168881, 0.0366222891428362, 0.0367937133216904, 0.0392650551244091, 0.0388595374824578, 0.0382698407848929, 0.0398901214808117, 0.041658832718701, 0.0405587448756974, 0.04328441823068, 0.0444012208191992, 0.0446093855124036, 0.0447741090438087, 0.0431679214267498, 0.0455872327272986, 0.0475613779730177, 0.0462317580933415, 0.0472115841774767, 0.0466770349318274, 0.0481140909
# ...

# %%
data=[]
#Aggregate Incident number by year
#new_total = crime_data.groupby('year')['IncidntNum'].sum().reset_index().rename(columns={'IncidntNum':'yeartotal'}) 
#Aggregate incident number by category by year and calculate proportion of each category per year.


for source in source_list:
    #new_df = crime_data.loc[crime_data['Category']==crime, ].groupby('year')['IncidntNum'].sum().reset_index()
    #new = new_df.merge(new_total, how = 'left', on ='year')
    #new['pert'] = new['IncidntNum']/new['yeartotal']*100
    
    trace =go.Bar(
                x=ef_person_BC['year'],
                y=ef_person_BC[source],
                name=source
        )
    data.append(trace)
    
layout = go.Layout(title = 'Figure 1.2 World Biocapacity per capita by source',
              xaxis = dict(title = 'Year', autotick=False),
              yaxis = dict(title = 'Biocapacity per capita'),
              barmode='stack',
              showlegend=True)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar-stacked')
# Out:
# <div id="5e03b60f-b6c6-4c3c-bb14-4b5738aade42" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5e03b60f-b6c6-4c3c-bb14-4b5738aade42", [{"y": [0.026267061753895, 0.027278565418383, 0.0274128251534238, 0.0281849376776406, 0.0285430405600116, 0.0303551263842964, 0.0311041599352478, 0.0316903676244591, 0.0320560276970156, 0.0329988627664111, 0.0346076561485223, 0.0337565142559032, 0.0355946788919016, 0.0346187728935319, 0.0350992216168881, 0.0366222891428362, 0.0367937133216904, 0.0392650551244091, 0.0388595374824578, 0.0382698407848929, 0.0398901214808117, 0.041658832718701, 0.0405587448756974, 0.04328441823068, 0.0444012208191992, 0.0446093855124036, 0.0447741090438087, 0.0431679214267498, 0.0455872327272986, 0.0475613779730177, 0.0462317580933415, 0.0472115841774767, 0.0466770349318274, 0.0481140909
# ...

# %% [markdown]
# ### EF and BC total GHA

# %%
ef_gha = pd.read_csv(os.path.join(path, "world/Ecological Footprint vs Biocapacity (gha).csv"))
ef_gha.head(5)
# Out:
#   Country Name Short Name  year        Record  Built-up Land        Carbon  \
# 0        World    º World  1961  EFConsTotGHA   8.077305e+07  3.091250e+09
# 1        World    º World  1961  BiocapTotGHA   8.077305e+07  0.000000e+00
# 2        World    º World  1962  EFConsTotGHA   8.547875e+07  3.225366e+09
# 3        World    º World  1962  BiocapTotGHA   8.547875e+07  0.000000e+00
# 4        World    º World  1963  EFConsTotGHA   8.755876e+07  3.452368e+09
#
#        Cropland  Fishing Grounds  Forest Products  Grazing Land         Total  \
# 0  1.428570e+09     2.940839e+08     1.324172e+09  8.163944e+08  7.035243e+09
# 1  1.428570e+09     1.127790e+09     5.496461e+09  1.477750e+09  9.611344e+09
# 2  1.488693e+09     3.075578e+08     1.335109e+09  8.237913e+08  7.265996e+09
# 3  1.488693e+09     1.125151e+09     5.491194e+09  1.477363e+09  9.667879e+09
# 4  1.506048e+09     3.172205e+08     1.347785e+09  8.396611e+08  7.550641e+09
#
#   Data Quality Score isoa2
# ...

# %%
ef_gha_EF=ef_gha.loc[ef_gha['Record']=='EFConsTotGHA'].reset_index()
ef_gha_BC=ef_gha.loc[ef_gha['Record']=='BiocapTotGHA'].reset_index()

# %%
source_list = ef_gha.columns.tolist()[4:10]
source_list
# Out:
# ['Built-up Land',
#  'Carbon',
#  'Cropland',
#  'Fishing Grounds',
#  'Forest Products',
#  'Grazing Land']

# %%
data=[]
#Aggregate Incident number by year
#new_total = crime_data.groupby('year')['IncidntNum'].sum().reset_index().rename(columns={'IncidntNum':'yeartotal'}) 
#Aggregate incident number by category by year and calculate proportion of each category per year.


for source in source_list:
    #new_df = crime_data.loc[crime_data['Category']==crime, ].groupby('year')['IncidntNum'].sum().reset_index()
    #new = new_df.merge(new_total, how = 'left', on ='year')
    #new['pert'] = new['IncidntNum']/new['yeartotal']*100
    
    trace =go.Bar(
                x=ef_gha_EF['year'],
                y=ef_gha_EF[source],
                name=source
        )
    data.append(trace)
    
layout = go.Layout(title = 'Figure 1.3 World Ecological Footprint (gha) by source',
              xaxis = dict(title = 'Year', autotick=False),
              yaxis = dict(title = 'Ecological Footprint (gha)'),
              barmode='stack',
              showlegend=True)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar-stacked')
# Out:
# <div id="bb5af31e-eab8-4937-aa28-ab338b4996d5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("bb5af31e-eab8-4937-aa28-ab338b4996d5", [{"y": [80773053.5875499, 85478748.6667741, 87558756.566048, 91798060.1666988, 94834252.2606386, 102924823.47997, 107662072.95027, 111992808.47381002, 115653980.64723101, 121517982.148681, 130046227.73898701, 129408973.051431, 139165227.957246, 137981081.684937, 142551978.674829, 151489563.930907, 154950100.785901, 168301020.478652, 169512685.810603, 169903933.24383402, 180247502.923196, 191588971.67330602, 189864002.099564, 206278820.585222, 215458700.073997, 220462259.765429, 225384357.845815, 221305961.02401802, 237918855.859117, 252535221.78199303, 249574286.66802797, 258961204.60356098, 259993418.422025, 272004352.767683, 270975975.224254, 290490979.63413, 29849
# ...

# %%
data=[]
#Aggregate Incident number by year
#new_total = crime_data.groupby('year')['IncidntNum'].sum().reset_index().rename(columns={'IncidntNum':'yeartotal'}) 
#Aggregate incident number by category by year and calculate proportion of each category per year.


for source in source_list:
    #new_df = crime_data.loc[crime_data['Category']==crime, ].groupby('year')['IncidntNum'].sum().reset_index()
    #new = new_df.merge(new_total, how = 'left', on ='year')
    #new['pert'] = new['IncidntNum']/new['yeartotal']*100
    
    trace =go.Bar(
                x=ef_gha_BC['year'],
                y=ef_gha_BC[source],
                name=source
        )
    data.append(trace)
    
layout = go.Layout(title = 'Figure 1.4 World Biocapacity(gha) by source',
              xaxis = dict(title = 'Year', autotick=False),
              yaxis = dict(title = 'Biocapacity (gha)'),
              barmode='stack',
              showlegend=True)

fig = go.Figure(data=data, layout=layout)
iplot(fig, filename='grouped-bar-stacked')
# Out:
# <div id="e921062b-1f39-4303-b43b-c54a5f18fb42" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e921062b-1f39-4303-b43b-c54a5f18fb42", [{"y": [80773053.5875499, 85478748.6667741, 87558756.566048, 91798060.1666988, 94834252.2606386, 102924823.47997, 107662072.95027, 111992808.47381002, 115653980.64723101, 121517982.148681, 130046227.73898701, 129408973.051431, 139165227.957246, 137981081.684937, 142551978.674829, 151489563.930907, 154950100.785901, 168301020.478652, 169512685.810603, 169903933.24383402, 180247502.923196, 191588971.67330602, 189864002.099564, 206278820.585222, 215458700.073997, 220462259.765429, 225384357.845815, 221305961.02401802, 237918855.859117, 252535221.78199303, 249574286.66802797, 258961204.60356098, 259993418.422025, 272004352.767683, 270975975.224254, 290490979.63413, 29849
# ...

# %%
second_plot_url = py.plot(fig, height=1000, width=1000, auto_open=False,\
                          filename='Major technology and CPG stock prices in 2014 - scatter matrix')
print (second_plot_url)
# Out:
# https://plot.ly/~fliu23/113
